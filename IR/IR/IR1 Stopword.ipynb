# %%
import nltk 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
nltk.download('stopwords') 
nltk.download('punkt') 
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Arpeet\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Arpeet\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Arpeet\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text_document = "Text preprocessing is an essential step in natural language processing. It includes tasks like stop word removal and stemming."

# %%
words = word_tokenize(text_document)
print("Tokenized Words:\n", words)
# Out:
# Tokenized Words:
#  ['Text', 'preprocessing', 'is', 'an', 'essential', 'step', 'in', 'natural', 'language', 'processing', '.', 'It', 'includes', 'tasks', 'like', 'stop', 'word', 'removal', 'and', 'stemming', '.']

# %%
stop_words = set(stopwords.words('english')) 
filtered_words = [word for word in words if word.lower() not in stop_words]
print("\nAfter Stopword Removal:\n", filtered_words)
# Out:
# After Stopword Removal:
#  ['Text', 'preprocessing', 'essential', 'step', 'natural', 'language', 'processing', '.', 'includes', 'tasks', 'like', 'stop', 'word', 'removal', 'stemming', '.']

# %%
stemmer = PorterStemmer() 
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("\nAfter Stemming:\n", stemmed_words)
# Out:
# After Stemming:
#  ['text', 'preprocess', 'essenti', 'step', 'natur', 'languag', 'process', '.', 'includ', 'task', 'like', 'stop', 'word', 'remov', 'stem', '.']

# %%
lemmatizer = WordNetLemmatizer() 
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("\nAfter Lemmatization:\n", lemmatized_words)
# Out:
# After Lemmatization:
#  ['Text', 'preprocessing', 'essential', 'step', 'natural', 'language', 'processing', '.', 'includes', 'task', 'like', 'stop', 'word', 'removal', 'stemming', '.']
